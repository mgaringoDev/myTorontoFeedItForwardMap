# %% [markdown]
# # Imports

# %%
import os, sys
import pandas as pd
import numpy as np
import folium

# %%
import urllib
import json

# %%
import pickle

# %% [markdown]
# # Functions

# %%
def getParentDir():
    cwd = os.getcwd()
    splits = cwd.split('\\')[:-1]
    parentDir = ''
    for s in splits:
        parentDir = parentDir + s + '\\'
    
    return parentDir

# %%
def getData(cached=False):
    pickleFile = getParentDir()+'data\\' + 'wards.pickle'    
    if cached:
        # lets pickle it
        pickleDict = pickle.load(open(pickleFile,"rb"))    
        df = pickleDict["data"]
        return df
    else:
        # Get the dataset metadata by passing package_id to the package_search endpoint
        # For example, to retrieve the metadata for this dataset:

        url = "https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/package_show"
        params = { "id": "5e7a8234-f805-43ac-820f-03d7c360b588"}
        response = urllib.request.urlopen(url, data=bytes(json.dumps(params), encoding="utf-8"))
        package = json.loads(response.read())
        print(package["result"])

        # Get the data by passing the resource_id to the datastore_search endpoint
        # See https://docs.ckan.org/en/latest/maintaining/datastore.html for detailed parameters options
        # For example, to retrieve the data content for the first resource in the datastore:

        for idx, resource in enumerate(package["result"]["resources"]):
            if resource["datastore_active"]:
                url = "https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/datastore_search"
                p = { "id": resource["id"] }
                r = urllib.request.urlopen(url, data=bytes(json.dumps(p), encoding="utf-8"))
                data = json.loads(r.read())
                df = pd.DataFrame(data["result"]["records"])
                break
        
        # pickle it        
        pickleDict = {"data":df}
        pickle.dump(pickleDict,open(pickleFile,"wb"))
        
        return df

# %% [markdown]
# # I/O

# %% [markdown]
# ## Reading the data
#
# Note that the data was from [Toronto Open Data](https://open.toronto.ca/dataset/city-wards/).

# %%
gdf = getData(cached=True)

# %%
gdf.head()
# Out:
#    _id  AREA_ID       DATE_EFFECTIVE          DATE_EXPIRY  AREA_ATTR_ID  \
# 0  835  2457731  2018-08-07T18:11:06  3000-01-01T05:00:00      25993187
# 1  836  2457730  2018-08-07T18:11:06  3000-01-01T05:00:00      25993186
# 2  837  2457729  2018-08-07T18:11:06  3000-01-01T05:00:00      25993185
# 3  838  2457728  2018-08-07T18:11:06  3000-01-01T05:00:00      25993184
# 4  839  2457727  2018-08-07T18:11:06  3000-01-01T05:00:00      25993183
#
#    AREA_TYPE_ID PARENT_AREA_ID AREA_TYPE AREA_CLASS_ID AREA_CLASS  ...  \
# 0           528           None      CITW          None       None  ...
# 1           528           None      CITW          None       None  ...
# 2           528           None      CITW          None       None  ...
# 3           528           None      CITW          None       None  ...
# 4           528           None      CITW          None       None  ...
#
#   TRANS_ID_CREATE TRANS_ID_EXPIRE     X     Y  LONGITUDE   LATITUDE  OBJECTID  \
# 0          279754              -1  None  None -79.276614  43.752739  17344929
# 1          279754              -1  None  None -79.308135  43.796483  17344945
# 2          279754              -1  None  None -79.375357  43.728396  17344961
# 3          279754              -1  None  None -79.413988  43.690530  17344977
# 4          279754              -1  None  None -79.467340  43.650121  17344993
#
#     Shape__Area Shape__Length  \
# 0  5.408523e+07  31081.950495
# 1  4.109341e+07  25980.702049
# 2  5.804883e+07  37532.814407
# 3  2.510962e+07  23816.299191
# 4  2.929313e+07  28220.033152
#
#                                             geometry
# 0  {"type": "Polygon", "coordinates": [[[-79.2502...
# 1  {"type": "Polygon", "coordinates": [[[-79.3164...
# 2  {"type": "Polygon", "coordinates": [[[-79.3523...
# 3  {"type": "Polygon", "coordinates": [[[-79.3887...
# 4  {"type": "Polygon", "coordinates": [[[-79.4693...
#
# [5 rows x 26 columns]

# %%
mygdf = gdf.copy()

# %%
mygdf
# Out:
#     _id  AREA_ID       DATE_EFFECTIVE          DATE_EXPIRY  AREA_ATTR_ID  \
# 0   835  2457731  2018-08-07T18:11:06  3000-01-01T05:00:00      25993187
# 1   836  2457730  2018-08-07T18:11:06  3000-01-01T05:00:00      25993186
# 2   837  2457729  2018-08-07T18:11:06  3000-01-01T05:00:00      25993185
# 3   838  2457728  2018-08-07T18:11:06  3000-01-01T05:00:00      25993184
# 4   839  2457727  2018-08-07T18:11:06  3000-01-01T05:00:00      25993183
# 5   840  2457726  2018-08-07T18:11:06  3000-01-01T05:00:00      25993182
# 6   841  2457725  2018-08-07T18:11:06  3000-01-01T05:00:00      25993181
# 7   842  2457724  2018-08-07T18:11:06  3000-01-01T05:00:00      25993180
# 8   843  2457723  2018-08-07T18:11:06  3000-01-01T05:00:00      25993179
# 9   844  2457722  2018-08-07T18:11:06  3000-01-01T05:00:00      25993178
# 10  845  2457721  2018-08-07T18:11:06  3000-01-01T05:00:00      25993177
# 11  846  2457720  2018-08-07T18:11:06  3000-01-01T05:00:00      25993176
# 12  847  2457719  2018-08-07T18:11:06  3000-01-01T05:00:00      25993175
# 13  848  2457718  2018-08-07T18:11:06  3000-01-01T05:00:00      25993174
# 14  849  2457717  2018-08-07T18:11:06  3000-01-01T05:00:00      25993173
# 15  850  2457716  2018-08-07T18:11:06  3000-01-01T05:00:00      25993172
# 16  826  2457740  2018-08-07T18:11:06  3000-01-01T05:00:00      25993196
# 17  827  2457739  2018-08-07T18:11:06  3000-01-01T05:00:00      25993195
# 18  828  2457738  2018-08-07T18:11:06  3000-01-01T05:00:00      25993194
# 19  829  2457737  2018-08-07T18:11:06  3000-01-01T05:00:00      25993193
# 20  830  2457736  2018-08-07T18:11:06  3000-01-01T05:00:00      25993192
# 21  831  2457735  2018-08-07T18:11:06  3000-01-01T05:00:00      25993191
# 22  832  2457734  2018-08-07T18:11:06  3000-01-01T05:00:00      25993190
# 23  833  2457733  2018-08-07T18:11:06  3000-01-01T05:00:00      25993189
# 24  834  2457732  2018-08-07T18:11:06  3000-01-01T05:00:00      25993188
#
#     AREA_TYPE_ID PARENT_AREA_ID AREA_TYPE AREA_CLASS_ID AREA_CLASS  ...  \
# 0            528           None      CITW          None       None  ...
# 1            528           None      CITW          None       None  ...
# 2            528           None      CITW          None       None  ...
# 3            528           None      CITW          None       None  ...
# 4            528           None      CITW          None       None  ...
# 5            528           None      CITW          None       None  ...
# 6            528           None      CITW          None       None  ...
# 7            528           None      CITW          None       None  ...
# 8            528           None      CITW          None       None  ...
# 9            528           None      CITW          None       None  ...
# 10           528           None      CITW          None       None  ...
# 11           528           None      CITW          None       None  ...
# 12           528           None      CITW          None       None  ...
# 13           528           None      CITW          None       None  ...
# 14           528           None      CITW          None       None  ...
# 15           528           None      CITW          None       None  ...
# 16           528           None      CITW          None       None  ...
# 17           528           None      CITW          None       None  ...
# 18           528           None      CITW          None       None  ...
# 19           528           None      CITW          None       None  ...
# 20           528           None      CITW          None       None  ...
# 21           528           None      CITW          None       None  ...
# 22           528           None      CITW          None       None  ...
# 23           528           None      CITW          None       None  ...
# 24           528           None      CITW          None       None  ...
#
#    TRANS_ID_CREATE TRANS_ID_EXPIRE     X     Y  LONGITUDE   LATITUDE  \
# 0           279754              -1  None  None -79.276614  43.752739
# 1           279754              -1  None  None -79.308135  43.796483
# 2           279754              -1  None  None -79.375357  43.728396
# 3           279754              -1  None  None -79.413988  43.690530
# 4           279754              -1  None  None -79.467340  43.650121
# 5           279754              -1  None  None -79.584667  43.719405
# 6           279754              -1  None  None -79.520874  43.621646
# 7           279754              -1  None  None -79.552534  43.664431
# 8           279754              -1  None  None -79.433849  43.718315
# 9           279754              -1  None  None -79.360039  43.787602
# 10          279754              -1  None  None -79.332981  43.739716
# 11          279754              -1  None  None -79.444047  43.669353
# 12          279754              -1  None  None -79.370101  43.660143
# 13          279754              -1  None  None -79.493371  43.694951
# 14          279754              -1  None  None -79.339250  43.665974
# 15          279754              -1  None  None -79.387335  43.635801
# 16          279754              -1  None  None -79.530272  43.750724
# 17          279754              -1  None  None -79.467810  43.752565
# 18          279754              -1  None  None -79.416500  43.776886
# 19          279754              -1  None  None -79.394317  43.671139
# 20          279754              -1  None  None -79.306673  43.689268
# 21          279754              -1  None  None -79.259794  43.713627
# 22          279754              -1  None  None -79.176842  43.805647
# 23          279754              -1  None  None -79.254671  43.809672
# 24          279754              -1  None  None -79.214663  43.765798
#
#     OBJECTID   Shape__Area Shape__Length  \
# 0   17344929  5.408523e+07  31081.950495
# 1   17344945  4.109341e+07  25980.702049
# 2   17344961  5.804883e+07  37532.814407
# 3   17344977  2.510962e+07  23816.299191
# 4   17344993  2.929313e+07  28220.033152
# 5   17345009  9.264135e+07  51338.921860
# 6   17345025  7.641257e+07  60137.672264
# 7   17345041  7.141052e+07  45328.643135
# 8   17345057  4.340675e+07  28793.624013
# 9   17345073  4.688259e+07  27888.817523
# 10  17345089  4.401710e+07  30862.987073
# 11  17345105  2.312941e+07  24054.749603
# 12  17345121  1.120816e+07  14958.064680
# 13  17345137  4.780773e+07  34744.117680
# 14  17345153  4.168548e+07  61191.203215
# 15  17345169  3.572418e+07  38163.556855
# 16  17344785  5.886873e+07  43438.943048
# 17  17344801  6.780539e+07  40910.174619
# 18  17344817  3.792649e+07  24766.996984
# 19  17344833  2.600299e+07  29861.631464
# 20  17344849  3.215503e+07  30975.878034
# 21  17344865  5.398787e+07  45132.346110
# 22  17344881  1.039006e+08  52384.382994
# 23  17344897  5.847579e+07  33292.578943
# 24  17344913  5.010259e+07  31659.059087
#
#                                              geometry
# 0   {"type": "Polygon", "coordinates": [[[-79.2502...
# 1   {"type": "Polygon", "coordinates": [[[-79.3164...
# 2   {"type": "Polygon", "coordinates": [[[-79.3523...
# 3   {"type": "Polygon", "coordinates": [[[-79.3887...
# 4   {"type": "Polygon", "coordinates": [[[-79.4693...
# 5   {"type": "Polygon", "coordinates": [[[-79.5793...
# 6   {"type": "Polygon", "coordinates": [[[-79.4977...
# 7   {"type": "Polygon", "coordinates": [[[-79.5276...
# 8   {"type": "Polygon", "coordinates": [[[-79.4645...
# 9   {"type": "Polygon", "coordinates": [[[-79.3834...
# 10  {"type": "Polygon", "coordinates": [[[-79.3133...
# 11  {"type": "Polygon", "coordinates": [[[-79.4464...
# 12  {"type": "Polygon", "coordinates": [[[-79.3771...
# 13  {"type": "Polygon", "coordinates": [[[-79.4693...
# 14  {"type": "Polygon", "coordinates": [[[-79.3321...
# 15  {"type": "Polygon", "coordinates": [[[-79.3837...
# 16  {"type": "Polygon", "coordinates": [[[-79.4910...
# 17  {"type": "Polygon", "coordinates": [[[-79.4404...
# 18  {"type": "Polygon", "coordinates": [[[-79.3944...
# 19  {"type": "Polygon", "coordinates": [[[-79.3900...
# 20  {"type": "Polygon", "coordinates": [[[-79.2986...
# 21  {"type": "Polygon", "coordinates": [[[-79.2790...
# 22  {"type": "Polygon", "coordinates": [[[-79.1647...
# 23  {"type": "Polygon", "coordinates": [[[-79.2259...
# 24  {"type": "Polygon", "coordinates": [[[-79.1819...
#
# [25 rows x 26 columns]

# %%
geoDict = eval(mygdf.iloc[0]['geometry'])

# %%
len(mygdf)
# Out:
# 25

# %%
geometryList = mygdf['geometry'].tolist()

# %%
coords = []
for geo in geometryList:
    geoDict = eval(geo)
    geoCoords = geoDict["coordinates"]
    coords.append(geoCoords)

# %%
mygdf["newGeo"] = coords

# %%
mygdf.head()
# Out:
#    _id  AREA_ID       DATE_EFFECTIVE          DATE_EXPIRY  AREA_ATTR_ID  \
# 0  835  2457731  2018-08-07T18:11:06  3000-01-01T05:00:00      25993187
# 1  836  2457730  2018-08-07T18:11:06  3000-01-01T05:00:00      25993186
# 2  837  2457729  2018-08-07T18:11:06  3000-01-01T05:00:00      25993185
# 3  838  2457728  2018-08-07T18:11:06  3000-01-01T05:00:00      25993184
# 4  839  2457727  2018-08-07T18:11:06  3000-01-01T05:00:00      25993183
#
#    AREA_TYPE_ID PARENT_AREA_ID AREA_TYPE AREA_CLASS_ID AREA_CLASS  ...  \
# 0           528           None      CITW          None       None  ...
# 1           528           None      CITW          None       None  ...
# 2           528           None      CITW          None       None  ...
# 3           528           None      CITW          None       None  ...
# 4           528           None      CITW          None       None  ...
#
#   TRANS_ID_EXPIRE     X     Y  LONGITUDE   LATITUDE  OBJECTID   Shape__Area  \
# 0              -1  None  None -79.276614  43.752739  17344929  5.408523e+07
# 1              -1  None  None -79.308135  43.796483  17344945  4.109341e+07
# 2              -1  None  None -79.375357  43.728396  17344961  5.804883e+07
# 3              -1  None  None -79.413988  43.690530  17344977  2.510962e+07
# 4              -1  None  None -79.467340  43.650121  17344993  2.929313e+07
#
#    Shape__Length                                           geometry  \
# 0   31081.950495  {"type": "Polygon", "coordinates": [[[-79.2502...
# 1   25980.702049  {"type": "Polygon", "coordinates": [[[-79.3164...
# 2   37532.814407  {"type": "Polygon", "coordinates": [[[-79.3523...
# 3   23816.299191  {"type": "Polygon", "coordinates": [[[-79.3887...
# 4   28220.033152  {"type": "Polygon", "coordinates": [[[-79.4693...
#
#                                               newGeo
# 0  [[[-79.2502110994834, 43.76863775512171], [-79...
# 1  [[[-79.3164533122312, 43.7683756940292], [-79....
# 2  [[[-79.3523211689513, 43.7157348777119], [-79....
# 3  [[[-79.38874183639071, 43.6917249723705], [-79...
# 4  [[[-79.4693442331409, 43.6672993773021], [-79....
#
# [5 rows x 27 columns]

# %%
mygdf['newGeo'] = eval(mygdf['geometry'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-b745dd1dc036> in <module>
# ----> 1 mygdf['newGeo'] = eval(mygdf['geometry'])
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
a
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[-79.2502110994834, 43.76863775512171],
#    [-79.2497371192295, 43.7674305432899],
#    [-79.2489583102213, 43.7654215375427],
#    [-79.2486256385713, 43.7645927071611],
#    [-79.2482072081534, 43.7634756490909],
#    [-79.2476087221297, 43.7619801332238],
#    [-79.2472408503818, 43.7610341962128],
#    [-79.2468833281571, 43.7601577159156],
#    [-79.2468513071832, 43.760079208682406],
#    [-79.2466700381705, 43.75961974665811],
#    [-79.2462219208663, 43.7583856171362],
#    [-79.2459511514404, 43.7576698712965],
#    [-79.2459118021982, 43.7575658471125],
#    [-79.2459079781613, 43.7575568284223],
#    [-79.2458203475569, 43.75734962425571],
#    [-79.2457512052702, 43.7571784478941],
#    [-79.2457028731893, 43.7570433225426],
#    [-79.2456368361459, 43.7568721620127],
#    [-79.2455924296487, 43.7567280441544],
#    [-79.2455557209569, 43.7566019457908],
#    [-79.2455143812809, 43.7564668359122],
#    [-79.2455132702884, 43.7564623328437],
#    [-79.2454813856339, 43.7561767531073],
#    [-79.2454718349617, 43.7559953308536],
#    [-79.2454722635462, 43.7558971468232],
#    [-79.24547265025771, 43.7558000518419],
#    [-79.24545528568, 43.7557306409949],
#    [-79.2454366117929, 43.7556185705848],
#    [-79.2454227767629, 43.755548528507106],
#    [-79.2432328661623, 43.7560026995996],
#    [-79.2432308774785, 43.7560031091868],
#    [-79.2431214575669, 43.7560268064877],
#    [-79.2422081592429, 43.7562245496478],
#    [-79.2413198392026, 43.7564168873153],
#    [-79.2401881819714, 43.7566618892242],
#    [-79.2382466530834, 43.7570895434464],
#    [-79.2352672256062, 43.7577217927048],
#    [-79.235238865603, 43.7574617097117],
#    [-79.2352583522142, 43.7570923190917],
#    [-79.2352983627602, 43.7567603579151],
#    [-79.2353034268332, 43.7566060172556],
#    [-79.2352364674023, 43.7564171162308],
#    [-79.2348770103665, 43.7555521777616],
#    [-79.2345478726787, 43.7547919563104],
#    [-79.2341678527394, 43.7539171473084],
#    [-79.2338358684458, 43.7531420019931],
#    [-79.2337969985084, 43.7530472999146],
#    [-79.23370414821561, 43.7528211446352],
#    [-79.2336839416114, 43.7527714289612],
#    [-79.2335584279283, 43.7524626384769],
#    [-79.253131022097, 43.7768285067432],
#    [-79.2529237091824, 43.7763075217974],
#    [-79.2525874742156, 43.7754384256137],
#    [-79.2523969082375, 43.774952427345],
#    [-79.2522399126702, 43.7745740923757],
#    [-79.252190818482, 43.7744632176507],
#    [-79.2518721140703, 43.7736494692383],
#    [-79.2517501911385, 43.7733134341036],
#    [-79.2516859688125, 43.7731335593639],
#    [-79.2516377758368, 43.7729765373657],
#    [-79.2516057018878, 43.7728626749516],
#    [-79.2515774448402, 43.7727420159424],
#    [-79.2515526393737, 43.7726217874813],
#    [-79.2515305519071, 43.7725081537735],
#    [-79.2515095262857, 43.7723930911826],
#    [-79.2514984298459, 43.77214202457],
#    [-79.2514255281135, 43.7719348392429],
#    [-79.2513322064066, 43.7716015931157],
#    [-79.251065026753, 43.7708809181929],
#    [-79.2508105259993, 43.7701834932131],
#    [-79.25076260364442, 43.7700521516887],
#    [-79.2504001981713, 43.76908823574511],
#    [-79.2502110994834, 43.76863775512171]]]}

# %% [markdown]
# ## Plotting the geometry

# %% [markdown]
# ### Generate dates

# %% [markdown]
# These dates will change based on the data Wes will give to me

# %%
n_periods, n_sample = 48, 40

assert n_sample < n_periods

datetime_index = pd.date_range('2016-1-1', periods=n_periods, freq='M')
dt_index_epochs = datetime_index.astype(int) // 10**9
dt_index = dt_index_epochs.astype('U10')

# %% [markdown]
# ### Generate some colour distributions based on some data

# %%
styledata = {}

for ward in gdf.index:
    df = pd.DataFrame(
        {'color': np.random.normal(size=n_periods),
         'opacity': np.random.normal(size=n_periods)},
        index=dt_index
    )
    df = df.cumsum()
    df.sample(n_sample, replace=False).sort_index()
    styledata[ward] = df

# %%
styledata.get(0).head()
# Out:
#                color   opacity
# 1454198400 -0.141749 -0.719620
# 1456704000 -1.656377 -1.386043
# 1459382400 -1.819541 -1.953582
# 1461974400 -2.723588 -1.127727
# 1464652800 -1.530062  0.412992

# %% [markdown]
# #### Colour Mapping

# %%
max_color, min_color, max_opacity, min_opacity = 0, 0, 0, 0

for country, data in styledata.items():
    max_color = max(max_color, data['color'].max())
    min_color = min(max_color, data['color'].min())
    max_opacity = max(max_color, data['opacity'].max())
    max_opacity = min(max_color, data['opacity'].max())

# %%
from branca.colormap import linear


cmap = linear.PuRd_09.scale(min_color, max_color)


def norm(x):
    return (x - x.min()) / (x.max() - x.min())


for country, data in styledata.items():
    data['color'] = data['color'].apply(cmap)
    data['opacity'] = norm(data['opacity'])

# %%
styledata.get(0).head()
# Out:
#                 color   opacity
# 1454198400  #f3eff7ff  0.796400
# 1456704000  #f7f4f9ff  0.726267
# 1459382400  #f7f4f9ff  0.666540
# 1461974400  #f7f4f9ff  0.753451
# 1464652800  #f7f4f9ff  0.915593

# %%
styledict = {
    str(ward): data.to_dict(orient='index') for
    ward, data in styledata.items()
}

# %% [markdown]
# ## Plotting the map

# %%
from folium.plugins import TimeSliderChoropleth

m = folium.Map([0, 0], tiles='Stamen Toner', zoom_start=2)

g = TimeSliderChoropleth(
    gdf.to_json(),
    styledict=styledict,

).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
